# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
print("Unit of Analysis:")
print("One row represents one content page for a reporting period.")

print("\nTime Window:")
print("March 2026")

print("\nPrediction Goal:")
print("Content Refresh Opportunity")
# Out:
# Unit of Analysis:
# One row represents one content page for a reporting period.
#
# Time Window:
# March 2026
#
# Prediction Goal:
# Content Refresh Opportunity

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
features = [
    "clicks",
    "impressions",
    "ctr",
    "position",
    "page_age"
]

label = "content_refresh"

context = [
    "month",
    "content_category"
]

excluded = [
    "future_metrics",
    "client_names",
    "urls",
    "label_derived_columns"
]

print("Features:", features)
print("Label:", label)
print("Context:", context)
print("Excluded:", excluded)
# Out:
# Features: ['clicks', 'impressions', 'ctr', 'position', 'page_age']
# Label: content_refresh
# Context: ['month', 'content_category']
# Excluded: ['future_metrics', 'client_names', 'urls', 'label_derived_columns']

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
print("Verification Query 1")
print("One row represents one content page.")

print("\nVerification Query 2")
print("Month selected: March 2026")

print("\nVerification Query 3")
print("Availability check: IS TRUE")
# Out:
# Verification Query 1
# One row represents one content page.
#
# Verification Query 2
# Month selected: March 2026
#
# Verification Query 3
# Availability check: IS TRUE

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
limitations = [
    "Single month of data",
    "Future information excluded",
    "Observational analysis only",
    "May not represent long-term trends"
]

for item in limitations:
    print("-", item)
# Out:
# - Single month of data
# - Future information excluded
# - Observational analysis only
# - May not represent long-term trends

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
