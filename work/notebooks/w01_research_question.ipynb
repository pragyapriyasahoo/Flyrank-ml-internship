# %% [markdown]
# <a href="https://colab.research.google.com/github/pragyapriyasahoo/Flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
### My Lane I chose the Content Refresh Prioritization lane because websites often have many pages, but only a limited amount of time to update them. My goal is to identify which pages should be refreshed first based on observable search performance metrics. This can help content teams focus their effort where it is most valuable.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
##### The Question Decision:Which pages should be refreshed first? Action: The SEO or content team updates the highest priority pages.Cost of a wrong recommendation: A valuable page may be ignored while time is spent updating pages with little impact. This can reduce traffic growth and waste resources.**Why ML helps:** Multiple search metrics interact with each other. A model can help identify useful patterns that are difficult to capture using simple manual rules.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/flyrank-bih/flyrank-ml-internship-starter
# Out:
# fatal: destination path 'flyrank-ml-internship-starter' already exists and is not an empty directory.

# %%
import pandas as pd

df = pd.read_csv("flyrank-ml-internship-starter/data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Average Impressions:", round(df["impressions_90d"].mean(), 2))
print(df["trend_direction"].value_counts())
# Out:
# Total pages: 30000
# Average CTR: 0.5107
# Average Impressions: 5200.37
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
### this provides decision support based on observed data the results describe patterns and relationships in the available dataset

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
